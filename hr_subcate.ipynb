# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/My Drive/hr_subcate/
# Out:
# /content/gdrive/My Drive/hr_subcate

# %%
# !ls
# Out:
# test_hr_subcate.csv  train_hr_subcate.csv

# %% [markdown]
# ### Import train, test Tech Group data of Technology Services department

# %% [markdown]
# ### Dataframe to Dataset

# %%
# !pip install datasets

# %%
import pandas as pd
train = pd.read_csv('train_hr_subcate.csv')
test = pd.read_csv('test_hr_subcate.csv')

# %%
# Calculate the sum of each row to determine the number of labels per description
rowsums = train.iloc[:, 1:].sum(axis=1)

# Count the number of descriptions without any label
no_label_count = (rowsums == 0).sum()

# Filter the DataFrame to exclude rows with no labels
train_df_new = train[rowsums != 0]

print(f"Number of descriptions without any label: {no_label_count}")
print(f"Shape of original DataFrame: {train.shape}")
print(f"Shape of filtered DataFrame: {train_df_new.shape}")
# Out:
# Number of descriptions without any label: 29
# Shape of original DataFrame: (7264, 88)
# Shape of filtered DataFrame: (7235, 88)

# %%
# Calculate the sum of each row to determine the number of labels per description
rowsums = test.iloc[:, 1:].sum(axis=1)

# Count the number of descriptions without any label
no_label_count = (rowsums == 0).sum()

# Filter the DataFrame to exclude rows with no labels
test_df_new = test[rowsums != 0]

print(f"Number of descriptions without any label: {no_label_count}")
print(f"Shape of original DataFrame: {test.shape}")
print(f"Shape of filtered DataFrame: {test_df_new.shape}")
# Out:
# Number of descriptions without any label: 7
# Shape of original DataFrame: (1816, 88)
# Shape of filtered DataFrame: (1809, 88)

# %%
train = train_df_new
test = test_df_new

# %%
from datasets import Dataset
train_dataset = Dataset.from_pandas(train)
test_dataset = Dataset.from_pandas(test)

# %%
train_dataset
# Out:
# Dataset({
#     features: ['Description', 'Viewing of pay slip in HRIS', 'TaaS | Sprout - Change in Personal Information', 'HRIS Log in Issue', 'ID/Badge Card Request', 'HRIS - Approver Account Creation\xa0', 'HRIS - Offboarding\xa0', 'HRIS - Work Information Update', 'EAA Updates\xa0', 'Other HRIS Concerns', 'Inaccurate Data Correction', 'Personal Data Updating', 'Complicated Report', 'Simple Report', 'Exit Management Concern', 'Employement Verification', 'OT Allowance reimbursement', 'Reimbursable allowance (part of compensation)', 'Endorsement for Salary Increase', 'Endorsement for Promotion', 'Endorsement for Lateral Movement', 'Endorsement for Communication Allowance', 'Other movement endorsement/process inquiries', 'Certificate of Employment Request', 'Non-Disclosure Agreement Request', 'Memo Request', 'Employment Contract / Consultancy Agreement request', 'Personal information update', 'Marriage Certificate/Birth Certificate/Death Certificate/Solo Parent ID upload', 'HRIS unlock request', 'HRIS approver change request', 'HRIS work schedule change request', 'HRIS filing error / system glitch', 'Cancellation of Leave/Schedule Adjustment/Official Business', 'Access level change', 'Location update', 'Other HRIS requests and inquiries', 'Incident Report template', 'Incident Report submission / Notice to Explain (NTE) issuance request', 'Return to Work Order Request', 'Generic inquiries – individual contributor', 'Team management-related inquiries – inquiries from people managers/leadership team (for People Managers only)', 'Certificate of Partial Completion', 'Certificate of Completion', 'Internship allowance follow up', 'Checking of current internship hours', 'Other Internship Inquiries', 'Paternity leave', 'Bereavement benefit', 'Solo parent leave', 'Maternity benefit', 'Company-initiated leave benefit', 'Special leave for women and other leave benefits', 'Compensatory Time Off', 'All mental health-related inquiries/requests', 'Request for Bonus / Incentive Computation', 'Request for Sample Payout Computation', 'Pay dispute/payroll concern', 'Request for Computation of Final Pay', 'Request for Computation of Intern Allowance', 'Verification of Salary Range Status', 'Request for Issuance of Authorization To Deduct', 'Concerns Related to Sprout and Savii Loans', 'Other Payroll-related concerns', 'Submission of Reimbursement Form and Receipts', '3rd Month Performance Review upload', '5th Month Performance Review upload', 'Coaching Logs upload', 'Request for Coaching Logs Form', 'Performance Improvement Plan Inquiry/Orientation', 'Other performance-related inquiries', 'Simple Reports', 'Complex Reports / Reports Requiring Analytics', 'Offboarding request (for People Managers only)', 'Clearance follow up', 'Offboarding-related inquiries', 'Request for Online Certification of Government Loan Application', 'Request for Continuation of Government Loan from Previous Employer', 'Request for Certificate of Contribution - SSS|Philhealth|Pag-Ibig', 'Request for Philhealth forms (for hospitalization purposes)', 'Request for Increase in Pag-Ibig Contribution', 'Request for Salary Deduction of MP2 savings', 'Request for TIN Verification', 'Other SSS, Philhealth, Pag-Ibig, and BIR Concerns', 'Eligibility for Rehire (for Talent Acquisition Only)', 'Credit Card/Cash Advance Limit (for Finance Only)', 'All other concerns raised to C&B Internal that do not fall under the above categories', 'PEX Pubmats/Collaterals Request', '__index_level_0__'],
#     num_rows: 7235
# })

# %% [markdown]
# ### Label Encoding

# %%
import os
def department_label_encoding(train_dataset):
    labels = [col for col in train_dataset.column_names if col != 'Description']
    labels = labels[:-1]
    label2id = {label: idx for idx, label in enumerate(labels)}
    id2label = {idx: label for label, idx in label2id.items()}
    print(label2id, id2label)
    return label2id, id2label

# %%
label2id, id2label = department_label_encoding(train_dataset)
# Out:
# {'Viewing of pay slip in HRIS': 0, 'TaaS | Sprout - Change in Personal Information': 1, 'HRIS Log in Issue': 2, 'ID/Badge Card Request': 3, 'HRIS - Approver Account Creation\xa0': 4, 'HRIS - Offboarding\xa0': 5, 'HRIS - Work Information Update': 6, 'EAA Updates\xa0': 7, 'Other HRIS Concerns': 8, 'Inaccurate Data Correction': 9, 'Personal Data Updating': 10, 'Complicated Report': 11, 'Simple Report': 12, 'Exit Management Concern': 13, 'Employement Verification': 14, 'OT Allowance reimbursement': 15, 'Reimbursable allowance (part of compensation)': 16, 'Endorsement for Salary Increase': 17, 'Endorsement for Promotion': 18, 'Endorsement for Lateral Movement': 19, 'Endorsement for Communication Allowance': 20, 'Other movement endorsement/process inquiries': 21, 'Certificate of Employment Request': 22, 'Non-Disclosure Agreement Request': 23, 'Memo Request': 24, 'Employment Contract / Consultancy Agreement request': 25, 'Personal information update': 26, 'Marriage Certificate/Birth Certificate/Death Certificate/Solo Parent ID upload': 27, 'HRIS unlock request': 28, 'HRIS approver change request': 29, 'HRIS work schedule change request': 30, 'HRIS filing error / system glitch': 31, 'Cancellation of Leave/Schedule Adjustment/Official Business': 32, 'Access level change': 33, 'Location update': 34, 'Other HRIS requests and inquiries': 35, 'Incident Report template': 36, 'Incident Report submission / Notice to Explain (NTE) issuance request': 37, 'Return to Work Order Request': 38, 'Generic inquiries – individual contributor': 39, 'Team management-related inquiries – inquiries from people managers/leadership team (for People Managers only)': 40, 'Certificate of Partial Completion': 41, 'Certificate of Completion': 42, 'Internship allowance follow up': 43, 'Checking of current internship hours': 44, 'Other Internship Inquiries': 45, 'Paternity leave': 46, 'Bereavement benefit': 47, 'Solo parent leave': 48, 'Maternity benefit': 49, 'Company-initiated leave benefit': 50, 'Special leave for women and other leave benefits': 51, 'Compensatory Time Off': 52, 'All mental health-related inquiries/requests': 53, 'Request for Bonus / Incentive Computation': 54, 'Request for Sample Payout Computation': 55, 'Pay dispute/payroll concern': 56, 'Request for Computation of Final Pay': 57, 'Request for Computation of Intern Allowance': 58, 'Verification of Salary Range Status': 59, 'Request for Issuance of Authorization To Deduct': 60, 'Concerns Related to Sprout and Savii Loans': 61, 'Other Payroll-related concerns': 62, 'Submission of Reimbursement Form and Receipts': 63, '3rd Month Performance Review upload': 64, '5th Month Performance Review upload': 65, 'Coaching Logs upload': 66, 'Request for Coaching Logs Form': 67, 'Performance Improvement Plan Inquiry/Orientation': 68, 'Other performance-related inquiries': 69, 'Simple Reports': 70, 'Complex Reports / Reports Requiring Analytics': 71, 'Offboarding request (for People Managers only)': 72, 'Clearance follow up': 73, 'Offboarding-related inquiries': 74, 'Request for Online Certification of Government Loan Application': 75, 'Request for Continuation of Government Loan from Previous Employer': 76, 'Request for Certificate of Contribution - SSS|Philhealth|Pag-Ibig': 77, 'Request for Philhealth forms (for hospitalization purposes)': 78, 'Request for Increase in Pag-Ibig Contribution': 79, 'Request for Salary Deduction of MP2 savings': 80, 'Request for TIN Verification': 81, 'Other SSS, Philhealth, Pag-Ibig, and BIR Concerns': 82, 'Eligibility for Rehire (for Talent Acquisition Only)': 83, 'Credit Card/Cash Advance Limit (for Finance Only)': 84, 'All other concerns raised to C&B Internal that do not fall under the above categories': 85, 'PEX Pubmats/Collaterals Request': 86} {0: 'Viewing of pay slip in HRIS', 1: 'TaaS | Sprout - Change in Personal Information', 2: 'HRIS Log in Issue', 3: 'ID/Badge Card Request', 4: 'HRIS - Approver Account Creation\xa0', 5: 'HRIS - Offboarding\xa0', 6: 'HRIS - Work Info ...

# %% [markdown]
# ### import model

# %%
# !pip install protobuf
# Out:
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (3.20.3)

# %%
from transformers import AutoTokenizer
model_path = 'tangminhanh/hr_cate'
tokenizer = AutoTokenizer.from_pretrained(model_path)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]

# %% [markdown]
# ### Tokenization Node

# %%
departments = [col for col in train_dataset.column_names if col != 'Description']
departments = departments[:-1]
departments
# Out:
# ['Viewing of pay slip in HRIS',
#  'TaaS | Sprout - Change in Personal Information',
#  'HRIS Log in Issue',
#  'ID/Badge Card Request',
#  'HRIS - Approver Account Creation\xa0',
#  'HRIS - Offboarding\xa0',
#  'HRIS - Work Information Update',
#  'EAA Updates\xa0',
#  'Other HRIS Concerns',
#  'Inaccurate Data Correction',
#  'Personal Data Updating',
#  'Complicated Report',
#  'Simple Report',
#  'Exit Management Concern',
#  'Employement Verification',
#  'OT Allowance reimbursement',
#  'Reimbursable allowance (part of compensation)',
#  'Endorsement for Salary Increase',
#  'Endorsement for Promotion',
#  'Endorsement for Lateral Movement',
#  'Endorsement for Communication Allowance',
#  'Other movement endorsement/process inquiries',
#  'Certificate of Employment Request',
#  'Non-Disclosure Agreement Request',
#  'Memo Request',
#  'Employment Contract / Consultancy Agreement request',
#  'Personal information update',
#  'Marriage Certificate/Birth Certificate/Death Certificate/Solo Parent ID upload',
#  'HRIS unlock request',
#  'HRIS approver change request',
#  'HRIS work schedule change request',
#  'HRIS filing error / system glitch',
#  'Cancellation of Leave/Schedule Adjustment/Official Business',
#  'Access level change',
#  'Location update',
#  'Other HRIS requests and inquiries',
#  'Incident Report template',
#  'Incident Report submission / Notice to Explain (NTE) issuance request',
#  'Return to Work Order Request',
#  'Generic inquiries – individual contributor',
#  'Team management-related inquiries – inquiries from people managers/leadership team (for People Managers only)',
#  'Certificate of Partial Completion',
#  'Certificate of Completion',
#  'Internship allowance follow up',
#  'Checking of current internship hours',
#  'Other Internship Inquiries',
#  'Paternity leave',
#  'Bereavement benefit',
#  'Solo parent leave',
#  'Maternity benefit',
#  'Company-initiated leave benefit',
#  'Special leave for women and other leave benefits',
#  'Compensatory Time Off',
#  'All mental health-related inquiries/requests',
#  'Request for Bonus / Incentive Computation',
#  'Request for Sample Payout Computation',
#  'Pay dispute/payroll concern',
#  'Request for Computation of Final Pay',
#  'Request for Computation of Intern Allowance',
#  'Verification of Salary Range Status',
#  'Request for Issuance of Authorization To Deduct',
#  'Concerns Related to Sprout and Savii Loans',
#  'Other Payroll-related concerns',
#  'Submission of Reimbursement Form and Receipts',
#  '3rd Month Performance Review upload',
#  '5th Month Performance Review upload',
#  'Coaching Logs upload',
#  'Request for Coaching Logs Form',
#  'Performance Improvement Plan Inquiry/Orientation',
#  'Other performance-related inquiries',
#  'Simple Reports',
#  'Complex Reports / Reports Requiring Analytics',
#  'Offboarding request (for People Managers only)',
#  'Clearance follow up',
#  'Offboarding-related inquiries',
#  'Request for Online Certification of Government Loan Application',
#  'Request for Continuation of Government Loan from Previous Employer',
#  'Request for Certificate of Contribution - SSS|Philhealth|Pag-Ibig',
#  'Request for Philhealth forms (for hospitalization purposes)',
#  'Request for Increase in Pag-Ibig Contribution',
#  'Request for Salary Deduction of MP2 savings',
#  'Request for TIN Verification',
#  'Other SSS, Philhealth, Pag-Ibig, and BIR Concerns',
#  'Eligibility for Rehire (for Talent Acquisition Only)',
#  'Credit Card/Cash Advance Limit (for Finance Only)',
#  'All other concerns raised to C&B Internal that do not fall under the above categories',
#  'PEX Pubmats/Collaterals Request']

# %%
def preprocess_function(example):
  text = example["Description"]
  labels = [0. for _ in range(len(departments))]
  for department in departments:
      if example[department] == 1:
          label_id = label2id[department]
          labels[label_id] = 1.

  example = tokenizer(text, truncation=True, padding='max_length', max_length=512)
  example['labels'] = labels
  return example

# %%
tokenized_train_dataset = train_dataset.map(preprocess_function)
tokenized_test_dataset = test_dataset.map(preprocess_function)
# Out:
# Map:   0%|          | 0/7235 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1809 [00:00<?, ? examples/s]

# %% [markdown]
# ### Train Model

# %%
# !pip install huggingface_hub
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.7.4)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !pip3 install transformers[torch] accelerate evaluate sentencepiece accelerate

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
import numpy as np

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = sigmoid(predictions)
    predictions = (predictions > 0.5).astype(int)

    # Compute metrics
    accuracy = accuracy_score(labels, predictions)
    f1 = f1_score(labels, predictions, average='micro')
    precision = precision_score(labels, predictions, average='micro')
    recall = recall_score(labels, predictions, average='micro')

    return {"accuracy": accuracy, "f1": f1, "precision": precision, "recall": recall}

# %%
len(label2id)
# Out:
# 87

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, Trainer, TrainingArguments, DataCollatorWithPadding

model = AutoModelForSequenceClassification.from_pretrained(
   model_path, num_labels=len(label2id),
           id2label=id2label, label2id=label2id,
                       problem_type = "multi_label_classification", ignore_mismatched_sizes=True)
# Out:
# config.json:   0%|          | 0.00/2.48k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/568M [00:00<?, ?B/s]
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at tangminhanh/hr_cate and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([24]) in the checkpoint and torch.Size([87]) in the model instantiated
# - classifier.weight: found shape torch.Size([24, 768]) in the checkpoint and torch.Size([87, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
training_args = TrainingArguments(
    output_dir='./hr_subcate',
    eval_strategy="epoch",
    learning_rate=2e-5,  # Adjusted learning rate
    per_device_train_batch_size=32,  # Increased batch size
    per_device_eval_batch_size=32,  # Increased eval batch size
    num_train_epochs=10,  # Increased epochs
    weight_decay=0.01,
)

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Initialize the trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_test_dataset,
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='2270' max='2270' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2270/2270 21:52, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.014265</td>
#       <td>0.732449</td>
#       <td>0.808290</td>
#       <td>0.902655</td>
#       <td>0.731788</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>0.013995</td>
#       <td>0.747374</td>
#       <td>0.810089</td>
#       <td>0.876123</td>
#       <td>0.753311</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.012200</td>
#       <td>0.012992</td>
#       <td>0.771697</td>
#       <td>0.828546</td>
#       <td>0.893930</td>
#       <td>0.772075</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.012200</td>
#       <td>0.013106</td>
#       <td>0.789386</td>
#       <td>0.831019</td>
#       <td>0.873479</td>
#       <td>0.792494</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.009200</td>
#       <td>0.012604</td>
#       <td>0.789939</td>
#       <td>0.838823</td>
#       <td>0.888820</td>
#       <td>0.794150</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.009200</td>
#       <td>0.012743</td>
#       <td>0.791045</td>
#       <td>0.838337</td>
#       <td>0.878935</td>
#       <td>0.801325</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.007300</td>
#       <td>0.012612</td>
#       <td>0.797678</td>
#       <td>0.842196</td>
#       <td>0.878824</td>
#       <td>0.808499</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.007300</td>
#       <td>0.012309</td>
#       <td>0.798784</td>
#       <td>0.843634</td>
#       <td>0.871689</td>
#       <td>0.817329</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.006100</td>
#       <td>0.012452</td>
#       <td>0.802653</td>
#       <td>0.845780</td>
#       <td>0.878194</td>
#       <td>0.815673</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.006100</td>
#       <td>0.012383</td>
#       <td>0.807076</td>
#       <td>0.847409</td>
#       <td>0.880428</td>
#       <td>0.816777</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2270, training_loss=0.008326226656657484, metrics={'train_runtime': 1313.4525, 'train_samples_per_second': 55.084, 'train_steps_per_second': 1.728, 'total_flos': 9598885655500800.0, 'train_loss': 0.008326226656657484, 'epoch': 10.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='57' max='57' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [57/57 00:10]
#     </div>
# {'eval_loss': 0.012383392080664635,
#  'eval_accuracy': 0.8070757324488668,
#  'eval_f1': 0.8474091039221301,
#  'eval_precision': 0.8804283164782868,
#  'eval_recall': 0.8167770419426048,
#  'eval_runtime': 10.8708,
#  'eval_samples_per_second': 166.41,
#  'eval_steps_per_second': 5.243,
#  'epoch': 10.0}

# %%
trainer.save_model('hr_techgroup')

# %%
trainer.push_to_hub('hr_subcate')
# Out:
# events.out.tfevents.1721721939.9cdcb57939d9.2051.2:   0%|          | 0.00/19.5k [00:00<?, ?B/s]
# training_args.bin:   0%|          | 0.00/5.11k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# events.out.tfevents.1721723264.9cdcb57939d9.2051.3:   0%|          | 0.00/560 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/568M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/tangminhanh/hr_subcate/commit/5d47b6082ed53296880d542a9cb28e8156da9b74', commit_message='hr_subcate', commit_description='', oid='5d47b6082ed53296880d542a9cb28e8156da9b74', pr_url=None, pr_revision=None, pr_num=None)
